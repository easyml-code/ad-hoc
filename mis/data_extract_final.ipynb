# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import datetime
import pandas as pd
import time
import warnings 
import chardet
warnings.filterwarnings("ignore")

def convert_date(date_str):
    # print(date_str,type(date_str))
    try:
        # input_date = datetime.strptime(date_str, '%d-%m-%Y')
        input_date = datetime.datetime.strptime(date_str, '%d-%m-%Y').date()
        month_abbr1, month_abbr2 = input_date.strftime('%b'), input_date.strftime('%B')
        day = input_date.day
        year = input_date.year
        last_day_of_month = input_date.replace(day=1) + timedelta(days=32)
        last_day_of_month = last_day_of_month.replace(day=1) - timedelta(days=1)
        last_day_of_month = last_day_of_month.day
        # print(last_day_of_month)
        if day <= 15:
            day = 15
            output_date_str5 = f"{month_abbr1}{day:02d}{last_day_of_month:02d}{year}"
            output_date_str6 = f"{month_abbr1}{day:02d}{last_day_of_month-1:02d}{year}"
            output_date_str7 = f"{month_abbr2}{day:02d}{last_day_of_month:02d}{year}"
            output_date_str8 = f"{month_abbr2}{day:02d}{last_day_of_month-1:02d}{year}"
        else:
            day = last_day_of_month
            output_date_str5 = f"{month_abbr1}{day:02d}{'15'}{year}"
            output_date_str6 = f"{month_abbr2}{day-1:02d}{'15'}{year}"
            output_date_str7 = f"{month_abbr2}{day:02d}{'15'}{year}"
            output_date_str8 = f"{month_abbr2}{day:02d}{'15'}{year}"
            
        output_date_str = f"{month_abbr1}{day:02d}{year}"
        output_date_str2 = f"{month_abbr1}{day-1:02d}{year}"
        output_date_str3 = f"{month_abbr2}{day:02d}{year}"
        output_date_str4 = f"{month_abbr2}{day-1:02d}{year}"
        
        url1=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str}.html"
        url2=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str2}.html"
        url3=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str}.html"
        url4=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str2}.html"
        url5=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str3}.html"
        url6=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str4}.html"
        url7=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str3}.html"
        url8=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str4}.html"
        url9=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector{output_date_str}.html"
        url10=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector{output_date_str2}.html"
        url11=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str}.html"
        url12=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str2}.html"
        url13=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector{output_date_str3}.html"
        url14=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector{output_date_str4}.html"
        url15=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str3}.html"
        url16=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str4}.html"
        url17=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str}.htm"
        url18=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str2}.htm"
        url19=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str}.htm"
        url20=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str2}.htm"
        url21=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str3}.htm"
        url22=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str4}.htm"
        url23=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str3}.htm"
        url24=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str4}.htm"
        url25=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector{output_date_str}.htm"
        url26=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector{output_date_str2}.htm"
        url27=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str}.htm"
        url28=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str2}.htm"
        url29=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector{output_date_str3}.htm"
        url30=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector{output_date_str4}.htm"
        url31=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str3}.htm"
        url32=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str4}.htm"

        url33= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str5}.html"
        url34= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str5}.htm"
        url35= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str5}.html"
        url36=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str5}.htm"
        url37= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str6}.html"
        url38= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str6}.htm"
        url39= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str6}.html"
        url40=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str6}.htm"
        
        url41= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str7}.html"
        url42= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str7}.htm"
        url43= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str7}.html"
        url44=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str7}.htm"
        url45= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str8}.html"
        url46= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInvestSector_{output_date_str8}.htm"
        url47= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str8}.html"
        url48=f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector{output_date_str8}.htm"

        url49= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str5}.htm"
        url50= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str6}.htm"
        url51= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str7}.htm"
        url52= f"https://www.fpi.nsdl.co.in/web/StaticReports/Fortnightly_Sector_wise_FII_Investment_Data/FIIInestSector_{output_date_str8}.htm"
        
        url=[url1,url2,url3,url4,url5,url6,url7,url8,url9,url10,url11,url12,url13,url14,url15,url16,url17,url18,url19,url20,url21,url22,url23,url24,url25,url26,url27,url28,url29,url30,url31,url32,url33,url34,url35,url36,url37,url38,url39,url40,url41,url42,url43,url44,url45,url46,url47,url48,url49,url50,url51,url52]
        return url
    except Exception as e:
        print(f'Error: {e}')
    
def convert_to_csv(date_str):
    url = convert_date(date_str)
    try:
        html_content,u=retrieve_html_content(url)
        soup = BeautifulSoup(html_content, 'html.parser')
        table = soup.find('table')
        # print(pd.read_html(str(tables[0]))[0][0])
        df = pd.read_html(str(table))[0]
        return df[df.iloc[:, 20].notna()]
    except Exception as e:
        print('Error 1',e)
        try:
            t1,t2=retrieve_html_content(url)
            t3 = convert_html_tables_to_csv(t2)
            return t3
        except Exception as e:
            print('Error 2',e)
            

def retrieve_html_content(url, headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}):
    for url in url:
        # print(url)
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            html_content = response.text
            return html_content,url
        except requests.exceptions.RequestException as e:
            continue

def retrieve_html_content1(url, retries=3):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    for attempt in range(retries):
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            return response.content
        except requests.exceptions.RequestException as e:
            print(f"Attempt {attempt + 1} failed: {e}")
            if attempt < retries - 1:
                sleep(2)  # wait for 2 seconds before retrying
            else:
                raise

def convert_html_tables_to_csv(url):
    html_content = retrieve_html_content1(url)
    result = chardet.detect(html_content)
    encoding = result['encoding']
    decoded_html_content = html_content.decode(encoding)
    soup = BeautifulSoup(decoded_html_content, 'html.parser')
    tables = soup.find_all('table')
    df = pd.read_html(str(tables[0]))[0]
    return df[df.iloc[:, 20].notna()]

def transform_data(df):
    # df_clean = df[df.iloc[:, 25].notna()]
    sectors = df_clean.iloc[:, 1].astype(str)
    unique_sectors = np.unique(sectors)
    cleaned_list = [s.replace(" ", "").lower() for s in unique_sectors]
    cleaned_list = set(cleaned_list)
    cleaned_list.remove('nan')
    cleaned_list.remove('sectors')
    cleaned_list.remove('grandtotal')
    columns = sorted(list(cleaned_list))
    columns = ['date', 'currency', 'asset_class'] + columns + ['grandtotal']
    data = pd.DataFrame(columns=columns)
    i, n = 0, len(df_clean)
    while i < n:
        if df_clean.iloc[i,1] == 'Sectors':
            store = {d: pd.Series([None] * 32) for d in columns}
            store['date'] = df_clean.iloc[i-2,2:]
            store['currency'] = df_clean.iloc[i-1,2:]
            store['asset_class'] = df_clean.iloc[i,2:]
            i += 1
            while i < n and not pd.isnull(df_clean.iloc[i, 1]):
                val = df_clean.iloc[i, 1].replace(' ', '').lower()
                store[val] = df_clean.iloc[i, 2:]
                i += 1
            new_data = pd.concat(store.values(), axis=1, keys=store.keys())
            data = pd.concat([data, new_data], axis=0)
        i += 1
    data = data.dropna(how = 'all')
    return data

def main():
    start_date=input("START DATE in YYYY-MM")
    end_date=input("END DATE in YYYY-MM")
    
    start_date_year, start_date_month = map(int, start_date.split("-"))
    start_date = datetime.date(start_date_year, start_date_month, 1)
    
    end_date_year, end_date_month = map(int, end_date.split("-"))
    end_date = datetime.date(start_date_year, start_date_month, 1)
    
    current_date = start_date
    dataframes = []
    while current_date <= end_date:
        first_day = datetime.date(current_date.year, current_date.month, 1)
        sixteenth_day = datetime.date(current_date.year, current_date.month, 16)
        temp1,temp2=str(first_day.strftime("%d-%m-%Y")),str(sixteenth_day.strftime("%d-%m-%Y"))
        df1, df2 = convert_to_csv(temp1), convert_to_csv(temp2)
        dataframes.append(df1)
        dataframes.append(df2)
        current_date = datetime.date(current_date.year, current_date.month, 28)
        current_date += datetime.timedelta(days=4)
        current_date = datetime.date(current_date.year, current_date.month, 1)
    
    combined_df = pd.concat(dataframes, ignore_index=True)
    transform_data(combined_df).to_csv(f"fortnightly_report_since_{start_date}_to_{sixteenth_day}.csv", index=False)
    print(f"Combined tables saved to fortnightly_report_since_{start_date}_to_{sixteenth_day}.csv")

if __name__=="__main__":
    main()
